# %%
import main
from databento import test_allocations as ta

# %%
for i in range(1, 11):
    ta.main(i)
# Out:
# Optimal Weights for Portfolio Longevity:
# biv: 1.82%
# blv: 0.51%
# bsv: 0.58%
# vb: 10.18%
# vo: 3.86%
# voo: 15.17%
# vti: 19.06%
# vtv: 10.32%
# vv: 24.87%
# vwo: 13.62%
# Portfolio Success Rate: 0.67
# Portfolio Expected Return: 0.09257641889664513
# Portfolio Standard Deviation: 0.14914516128566196
# Optimal Weights for Portfolio Longevity:
# biv: 1.31%
# blv: 2.57%
# bsv: 8.52%
# vb: 2.47%
# vo: 25.30%
# voo: 17.33%
# vti: 4.27%
# vtv: 11.52%
# vv: 25.41%
# vwo: 1.29%
# Portfolio Success Rate: 0.698
# Portfolio Expected Return: 0.09317545862341516
# Portfolio Standard Deviation: 0.14395350408773874
# Optimal Weights for Portfolio Longevity:
# biv: 1.44%
# blv: 0.61%
# bsv: 8.67%
# vb: 15.53%
# vo: 8.53%
# voo: 21.68%
# vti: 7.44%
# vtv: 13.91%
# vv: 16.05%
# vwo: 6.13%
# Portfolio Success Rate: 0.612
# Portfolio Expected Return: 0.08168869569272368
# Portfolio Standard Deviation: 0.13779323255465847
# Optimal Weights for Portfolio Longevity:
# biv: 0.16%
# blv: 0.08%
# ...
