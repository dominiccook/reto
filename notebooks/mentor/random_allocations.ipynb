# %% [markdown]
# ## TEST 3
# Initial simulations with some randomized target allocations.
# Ran with mentors initial portfolio.

# %%
from mentor import test_allocations as ta

# %%
for i in range(1, 11):
    ta.main(i)
# Out:
# Optimal Weights for Portfolio Longevity:
# vfiax: 15.98%
# vexax: 19.72%
# vgslx: 6.91%
# vdipx: 9.42%
# vemax: 19.00%
# vgpmx: 17.30%
# vbtlx: 7.37%
# vaipx: 0.75%
# vusxx: 1.14%
# cash: 2.41%
# Portfolio Success Rate: 0.615
# Portfolio Expected Return: 0.08980518298935762
# Portfolio Standard Deviation: 0.14295061734873588
# Optimal Weights for Portfolio Longevity:
# vfiax: 11.51%
# vexax: 13.31%
# vgslx: 19.78%
# vdipx: 25.72%
# vemax: 14.57%
# vgpmx: 7.37%
# vbtlx: 1.16%
# vaipx: 2.53%
# vusxx: 0.48%
# cash: 3.57%
# Portfolio Success Rate: 0.666
# Portfolio Expected Return: 0.08555448597770936
# Portfolio Standard Deviation: 0.1493712913343484
# Optimal Weights for Portfolio Longevity:
# vfiax: 20.94%
# vexax: 5.18%
# vgslx: 1.21%
# vdipx: 17.22%
# vemax: 27.33%
# vgpmx: 16.95%
# vbtlx: 0.54%
# vaipx: 6.70%
# vusxx: 2.03%
# cash: 1.91%
# Portfolio Success Rate: 0.655
# Portfolio Expected Return: 0.08550170481850397
# Portfolio Standard Deviation: 0.15161109316605276
# ...
