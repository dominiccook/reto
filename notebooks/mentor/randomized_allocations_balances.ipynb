# %% [markdown]
# ## TEST 4
# Randomized balances and target allocations with mentor's metrics

# %%
from mentor import test_allocations as ta

# %%
for i in range(1, 11):
    ta.main(i)
# Out:
# Optimal Weights for Portfolio Longevity:
# vfiax: 13.58%
# vexax: 15.09%
# vgslx: 20.01%
# vdipx: 7.99%
# vemax: 20.39%
# vgpmx: 9.77%
# vbtlx: 7.51%
# vaipx: 0.33%
# vusxx: 2.56%
# cash: 2.76%
# Portfolio Success Rate: 0.617
# Portfolio Expected Return: 0.08270443223737432
# Portfolio Standard Deviation: 0.13638837848783156
# Optimal Weights for Portfolio Longevity:
# vfiax: 17.45%
# vexax: 13.69%
# vgslx: 19.10%
# vdipx: 15.24%
# vemax: 17.58%
# vgpmx: 4.29%
# vbtlx: 8.71%
# vaipx: 1.51%
# vusxx: 1.64%
# cash: 0.79%
# Portfolio Success Rate: 0.643
# Portfolio Expected Return: 0.07787786944952889
# Portfolio Standard Deviation: 0.142350183485703
# Optimal Weights for Portfolio Longevity:
# vfiax: 21.34%
# vexax: 19.62%
# vgslx: 0.13%
# vdipx: 20.98%
# vemax: 20.32%
# vgpmx: 8.51%
# vbtlx: 3.91%
# vaipx: 2.39%
# vusxx: 2.47%
# cash: 0.33%
# Portfolio Success Rate: 0.639
# Portfolio Expected Return: 0.09336669082777826
# Portfolio Standard Deviation: 0.15806729694890514
# ...
