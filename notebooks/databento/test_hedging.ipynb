# %%
import numpy as np
from databento import test_hedges as th

# %%
draws = np.random.uniform(size=5)
print(draws)
# Out:
# [0.24298842 0.67593638 0.1139502  0.91550321 0.71853166]

# %%
for random_hedge in draws:
    print(f" Hedge {random_hedge}")
    th.hedge(random_hedge)
# Out:
#  Hedge 0.24298841559058515
# Optimal Weights for Portfolio Longevity:
# biv: 2.40%
# blv: 6.98%
# bsv: 1.04%
# vb: 10.10%
# vo: 8.13%
# voo: 15.25%
# vti: 6.16%
# vtv: 17.77%
# vv: 26.44%
# vwo: 5.74%
# Portfolio Success Rate: 0.64
# Portfolio Expected Return: 0.08764028617205032
# Portfolio Standard Deviation: 0.14554744874009914
#  Hedge 0.6759363763093537
# Optimal Weights for Portfolio Longevity:
# biv: 0.47%
# blv: 0.92%
# bsv: 2.88%
# vb: 14.43%
# vo: 10.90%
# voo: 14.81%
# vti: 20.41%
# vtv: 12.48%
# vv: 16.54%
# vwo: 6.16%
# Portfolio Success Rate: 0.643
# Portfolio Expected Return: 0.09040006921167744
# Portfolio Standard Deviation: 0.1528748842571837
#  Hedge 0.11395020172150694
# Optimal Weights for Portfolio Longevity:
# biv: 3.12%
# blv: 1.97%
# bsv: 6.95%
# vb: 1.21%
# vo: 34.18%
# voo: 10.31%
# vti: 7.06%
# vtv: 6.63%
# vv: 25.23%
# vwo: 3.34%
# Portfolio Success Rate: 0.722
# Portfolio Expected Return: 0.09688244826576538
# ...
