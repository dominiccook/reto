# %% [markdown]
# ## TEST 2
# These simulations were created with randomized starting balances and target_allocations.
#
# You may notice some notably improved success rates compared to the first test.

# %%
import main
from databento import test_allocations as ta

# %%
for i in range(1, 11):
    ta.main(i)
# Out:
# Optimal Weights for Portfolio Longevity:
# biv: 2.81%
# blv: 3.24%
# bsv: 2.70%
# vb: 3.77%
# vo: 12.81%
# voo: 11.95%
# vti: 18.98%
# vtv: 17.14%
# vv: 20.53%
# vwo: 6.05%
# Portfolio Success Rate: 0.666
# Portfolio Expected Return: 0.0818801262057904
# Portfolio Standard Deviation: 0.14449267481166594
# Optimal Weights for Portfolio Longevity:
# biv: 2.44%
# blv: 0.99%
# bsv: 1.21%
# vb: 0.04%
# vo: 13.63%
# voo: 21.98%
# vti: 18.80%
# vtv: 14.27%
# vv: 19.81%
# vwo: 6.83%
# Portfolio Success Rate: 0.701
# Portfolio Expected Return: 0.09800610913573106
# Portfolio Standard Deviation: 0.13748416336136188
# Optimal Weights for Portfolio Longevity:
# biv: 0.45%
# blv: 2.28%
# bsv: 5.77%
# vb: 1.99%
# vo: 18.53%
# voo: 21.19%
# vti: 8.37%
# vtv: 14.51%
# vv: 26.36%
# vwo: 0.56%
# Portfolio Success Rate: 0.762
# Portfolio Expected Return: 0.09706560379814609
# Portfolio Standard Deviation: 0.14089064677923202
# Optimal Weights for Portfolio Longevity:
# biv: 0.87%
# blv: 3.66%
# ...
