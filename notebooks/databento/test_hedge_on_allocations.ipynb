# %%
from databento import hedge_allocations as ha
import numpy as np

# %%
draws = np.random.uniform(size=4)
for draw in draws: 
    print(f"hedge ratio: {draw}") 
    ha.main(hedge=draw, file_number=1)
# Out:
# hedge ratio: 0.33062702439136615
# Optimal Weights for Portfolio Longevity:
# biv: 1.29%
# blv: 1.37%
# bsv: 10.86%
# vb: 18.25%
# vo: 22.31%
# voo: 1.26%
# vti: 16.31%
# vtv: 6.58%
# vv: 20.97%
# vwo: 0.80%
# Portfolio Success Rate: 0.65
# Portfolio Expected Return: 0.08948458762687517
# Portfolio Standard Deviation: 0.16592709592357888
# hedge ratio: 0.04865370733069918
# Optimal Weights for Portfolio Longevity:
# biv: 1.86%
# blv: 2.59%
# bsv: 3.45%
# vb: 13.78%
# vo: 14.24%
# voo: 15.58%
# vti: 15.09%
# vtv: 3.25%
# vv: 22.71%
# vwo: 7.46%
# Portfolio Success Rate: 0.599
# Portfolio Expected Return: 0.08891162127793172
# Portfolio Standard Deviation: 0.15482728245883368
# hedge ratio: 0.5080288797294793
# Optimal Weights for Portfolio Longevity:
# biv: 0.85%
# blv: 3.05%
# bsv: 4.15%
# vb: 18.62%
# vo: 12.46%
# voo: 7.96%
# vti: 22.10%
# vtv: 3.51%
# vv: 21.31%
# vwo: 6.00%
# Portfolio Success Rate: 0.632
# Portfolio Expected Return: 0.07964305717004365
# ...

# %%
ha.main(hedge=1, file_number=1)
# Out:
# Optimal Weights for Portfolio Longevity:
# biv: 3.32%
# blv: 2.70%
# bsv: 3.86%
# vb: 24.34%
# vo: 8.02%
# voo: 3.26%
# vti: 15.63%
# vtv: 15.73%
# vv: 22.24%
# vwo: 0.90%
# Portfolio Success Rate: 0.708
# Portfolio Expected Return: 0.08557257732699439
# Portfolio Standard Deviation: 0.16554792373251231
