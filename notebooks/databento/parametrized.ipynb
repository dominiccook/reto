# %%
import Modern_Portfolio_Success_Rate as sr

# %%
# Correct file inputs to account for relative path
#+to the notebook directory.
file1 = "../../data/returns_std_devs.csv"
file2 = "../../data/index_correlations.csv"
file3 = "../../data/balances_and_target_allocations.csv"

path_to_config = "../../config/logger/config.json"

# %%
sr.success_rate(returns_std_devs=file1, index_correlations=file2, balances_and_target_allocations=file3)

# %%
sr.success_rate(returns_std_devs=file1, 
                index_correlations=file2, 
                balances_and_target_allocations=file3, 
                necessary_drawdown=0.2)

# %%
sr.success_rate(returns_std_devs=file1, 
                index_correlations=file2, 
                balances_and_target_allocations=file3, 
                necessary_drawdown=0.02)

# %%
sr.success_rate(returns_std_devs=file1, 
                index_correlations=file2, 
                balances_and_target_allocations=file3, 
                necessary_drawdown=0.01)

# %%
sr.success_rate(returns_std_devs=file1, 
                index_correlations=file2, 
                balances_and_target_allocations=file3, 
                necessary_drawdown=0.01)

# %%
sr.success_rate(returns_std_devs=file1, 
                index_correlations=file2, 
                balances_and_target_allocations=file3,
                necessary_drawdown= 0.02,
                starting_balance=5000000)
# Out:
#  Retiring with initial balance of 5000000
#  and an annual withdrawal of 438390.60187070956
#  for 50 years, yields:
# Optimal Weights for Portfolio Longevity:
# biv: 10.51%
# blv: 4.83%
# bsv: 3.96%
# vb: 2.74%
# vo: 10.48%
# voo: 20.21%
# vti: 4.78%
# vtv: 19.56%
# vv: 21.55%
# vwo: 1.39%
# Portfolio Success Rate: 0.973
# Portfolio Expected Return: 0.08130282269396893
# Portfolio Standard Deviation: 0.12572086214896705

# %%
sr.success_rate(returns_std_devs=file1, 
                index_correlations=file2, 
                balances_and_target_allocations=file3,
                necessary_drawdown=0.0001,
                starting_balance=10000000)
# Out:
#  Retiring with initial balance of 10000000
#  and an annual withdrawal of 0.0001
#  for 50 years, yields:
# Optimal Weights for Portfolio Longevity:
# biv: 19.88%
# blv: 1.25%
# bsv: 7.74%
# vb: 2.46%
# vo: 9.86%
# voo: 6.82%
# vti: 24.42%
# vtv: 9.21%
# vv: 13.19%
# vwo: 5.18%
# Portfolio Success Rate: 1.0
# Portfolio Expected Return: 0.06305243543374
# Portfolio Standard Deviation: 0.12529013330084018
